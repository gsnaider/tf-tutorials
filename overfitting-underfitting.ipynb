# %% [markdown]
# # Explore overfitting and underfitting

# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.11.0

# %% [markdown]
# ## Download the IMDB dataset

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %% [markdown]
# ## Demonstrate overfitting

# %% [markdown]
# ### Create a baseline model

# %%
baseline_model = keras.Sequential([
    # `input_shape` is only required here so that `.summary` works. 
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 6s - loss: 0.5058 - acc: 0.7839 - binary_crossentropy: 0.5058 - val_loss: 0.3513 - val_acc: 0.8754 - val_binary_crossentropy: 0.3513
# Epoch 2/20
#  - 2s - loss: 0.2572 - acc: 0.9101 - binary_crossentropy: 0.2572 - val_loss: 0.2855 - val_acc: 0.8872 - val_binary_crossentropy: 0.2855
# Epoch 3/20
#  - 2s - loss: 0.1840 - acc: 0.9358 - binary_crossentropy: 0.1840 - val_loss: 0.2884 - val_acc: 0.8857 - val_binary_crossentropy: 0.2884
# Epoch 4/20
#  - 2s - loss: 0.1442 - acc: 0.9512 - binary_crossentropy: 0.1442 - val_loss: 0.3139 - val_acc: 0.8797 - val_binary_crossentropy: 0.3139
# Epoch 5/20
#  - 2s - loss: 0.1164 - acc: 0.9628 - binary_crossentropy: 0.1164 - val_loss: 0.3412 - val_acc: 0.8747 - val_binary_crossentropy: 0.3412
# Epoch 6/20
#  - 2s - loss: 0.0929 - acc: 0.9729 - binary_crossentropy: 0.0929 - val_loss: 0.3738 - val_acc: 0.8710 - val_binary_crossentropy: 0.3738
# Epoch 7/20
#  - 3s - loss: 0.0741 - acc: 0.9806 - binary_crossentropy: 0.0741 - val_loss: 0.4217 - val_acc: 0.8647 - val_binary_crossentropy: 0.4217
# Epoch 8/20
#  - 3s - loss: 0.0588 - acc: 0.9852 - binary_crossentropy: 0.0588 - val_loss: 0.4554 - val_acc: 0.8640 - val_binary_crossentropy: 0.4554
# Epoch 9/20
#  - 3s - loss: 0.0457 - acc: 0.9908 - binary_crossentropy: 0.0457 - val_loss: 0.4916 - val_acc: 0.8634 - val_binary_crossentropy: 0.4916
# Epoch 10/20
#  - 2s - loss: 0.0344 - acc: 0.9940 - binary_crossentropy: 0.0344 - val_loss: 0.5333 - val_acc: 0.8592 - val_binary_crossentropy: 0.5333
# Epoch 11/20
#  - 2s - loss: 0.0259 - acc: 0.9966 - binary_crossentropy: 0.0259 - val_loss: 0.5749 - val_acc: 0.8594 - val_binary_crossentropy: 0.5749
# Epoch 12/20
#  - 3s - loss: 0.0197 - acc: 0.9978 - binary_crossentropy: 0.0197 - val_loss: 0.6135 - val_acc: 0.8584 - val_binary_crossentropy: 0.6135
# Epoch 13/20
#  - 2s - loss: 0.0147 - acc: 0.9986 - binary_crossentropy: 0.0147 - val_loss: 0.6466 - val_acc: 0.8580 - val_binary_crossentropy: 0.6466
# Epoch 14/20
#  - 2s - loss: 0.0111 - acc: 0.9994 - binary_crossentropy: 0.0111 - val_loss: 0.6787 - val_acc: 0.8568 - val_binary_crossentropy: 0.6787
# Epoch 15/20
#  - 2s - loss: 0.0085 - acc: 0.9998 - binary_crossentropy: 0.0085 - val_loss: 0.7084 - val_acc: 0.8567 - val_binary_crossentropy: 0.7084
# Epoch 16/20
#  - 2s - loss: 0.0068 - acc: 0.9998 - binary_crossentropy: 0.0068 - val_loss: 0.7353 - val_acc: 0.8560 - val_binary_crossentropy: 0.7353
# Epoch 17/20
#  - 2s - loss: 0.0054 - acc: 0.9998 - binary_crossentropy: 0.0054 - val_loss: 0.7595 - val_acc: 0.8567 - val_binary_crossentropy: 0.7595
# Epoch 18/20
#  - 3s - loss: 0.0044 - acc: 0.9999 - binary_crossentropy: 0.0044 - val_loss: 0.7855 - val_acc: 0.8560 - val_binary_crossentropy: 0.7855
# Epoch 19/20
#  - 3s - loss: 0.0035 - acc: 0.9999 - binary_crossentropy: 0.0035 - val_loss: 0.8137 - val_acc: 0.8560 - val_binary_crossentropy: 0.8137
# Epoch 20/20
#  - 3s - loss: 0.0027 - acc: 1.0000 - binary_crossentropy: 0.0027 - val_loss: 0.8406 - val_acc: 0.8554 - val_binary_crossentropy: 0.8406

# %% [markdown]
# ### Create a smaller model

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam',
                loss='binary_crossentropy',
                metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 4s - loss: 0.6384 - acc: 0.6754 - binary_crossentropy: 0.6384 - val_loss: 0.5776 - val_acc: 0.7916 - val_binary_crossentropy: 0.5776
# Epoch 2/20
#  - 3s - loss: 0.4961 - acc: 0.8526 - binary_crossentropy: 0.4961 - val_loss: 0.4480 - val_acc: 0.8578 - val_binary_crossentropy: 0.4480
# Epoch 3/20
#  - 3s - loss: 0.3578 - acc: 0.9004 - binary_crossentropy: 0.3578 - val_loss: 0.3488 - val_acc: 0.8805 - val_binary_crossentropy: 0.3488
# Epoch 4/20
#  - 3s - loss: 0.2668 - acc: 0.9211 - binary_crossentropy: 0.2668 - val_loss: 0.3056 - val_acc: 0.8875 - val_binary_crossentropy: 0.3056
# Epoch 5/20
#  - 3s - loss: 0.2178 - acc: 0.9324 - binary_crossentropy: 0.2178 - val_loss: 0.2905 - val_acc: 0.8873 - val_binary_crossentropy: 0.2905
# Epoch 6/20
#  - 3s - loss: 0.1870 - acc: 0.9404 - binary_crossentropy: 0.1870 - val_loss: 0.2853 - val_acc: 0.8886 - val_binary_crossentropy: 0.2853
# Epoch 7/20
#  - 3s - loss: 0.1651 - acc: 0.9489 - binary_crossentropy: 0.1651 - val_loss: 0.2879 - val_acc: 0.8867 - val_binary_crossentropy: 0.2879
# Epoch 8/20
#  - 3s - loss: 0.1483 - acc: 0.9537 - binary_crossentropy: 0.1483 - val_loss: 0.2937 - val_acc: 0.8849 - val_binary_crossentropy: 0.2937
# Epoch 9/20
#  - 3s - loss: 0.1351 - acc: 0.9589 - binary_crossentropy: 0.1351 - val_loss: 0.3028 - val_acc: 0.8834 - val_binary_crossentropy: 0.3028
# Epoch 10/20
#  - 3s - loss: 0.1225 - acc: 0.9638 - binary_crossentropy: 0.1225 - val_loss: 0.3149 - val_acc: 0.8805 - val_binary_crossentropy: 0.3149
# Epoch 11/20
#  - 3s - loss: 0.1114 - acc: 0.9682 - binary_crossentropy: 0.1114 - val_loss: 0.3261 - val_acc: 0.8784 - val_binary_crossentropy: 0.3261
# Epoch 12/20
#  - 3s - loss: 0.1004 - acc: 0.9711 - binary_crossentropy: 0.1004 - val_loss: 0.3424 - val_acc: 0.8750 - val_binary_crossentropy: 0.3424
# Epoch 13/20
#  - 3s - loss: 0.0899 - acc: 0.9756 - binary_crossentropy: 0.0899 - val_loss: 0.3553 - val_acc: 0.8738 - val_binary_crossentropy: 0.3553
# Epoch 14/20
#  - 3s - loss: 0.0806 - acc: 0.9800 - binary_crossentropy: 0.0806 - val_loss: 0.3708 - val_acc: 0.8720 - val_binary_crossentropy: 0.3708
# Epoch 15/20
#  - 3s - loss: 0.0715 - acc: 0.9837 - binary_crossentropy: 0.0715 - val_loss: 0.3875 - val_acc: 0.8704 - val_binary_crossentropy: 0.3875
# Epoch 16/20
#  - 3s - loss: 0.0636 - acc: 0.9863 - binary_crossentropy: 0.0636 - val_loss: 0.4046 - val_acc: 0.8691 - val_binary_crossentropy: 0.4046
# Epoch 17/20
#  - 3s - loss: 0.0567 - acc: 0.9886 - binary_crossentropy: 0.0567 - val_loss: 0.4219 - val_acc: 0.8676 - val_binary_crossentropy: 0.4219
# Epoch 18/20
#  - 3s - loss: 0.0503 - acc: 0.9914 - binary_crossentropy: 0.0503 - val_loss: 0.4399 - val_acc: 0.8651 - val_binary_crossentropy: 0.4399
# Epoch 19/20
#  - 3s - loss: 0.0450 - acc: 0.9928 - binary_crossentropy: 0.0450 - val_loss: 0.4545 - val_acc: 0.8664 - val_binary_crossentropy: 0.4545
# Epoch 20/20
#  - 3s - loss: 0.0405 - acc: 0.9941 - binary_crossentropy: 0.0405 - val_loss: 0.4733 - val_acc: 0.8640 - val_binary_crossentropy: 0.4733

# %% [markdown]
# ### Create a bigger model

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 5s - loss: 0.3503 - acc: 0.8500 - binary_crossentropy: 0.3503 - val_loss: 0.2926 - val_acc: 0.8822 - val_binary_crossentropy: 0.2926
# Epoch 2/20
#  - 5s - loss: 0.1389 - acc: 0.9496 - binary_crossentropy: 0.1389 - val_loss: 0.3541 - val_acc: 0.8644 - val_binary_crossentropy: 0.3541
# Epoch 3/20
#  - 5s - loss: 0.0461 - acc: 0.9871 - binary_crossentropy: 0.0461 - val_loss: 0.4351 - val_acc: 0.8687 - val_binary_crossentropy: 0.4351
# Epoch 4/20
#  - 5s - loss: 0.0075 - acc: 0.9988 - binary_crossentropy: 0.0075 - val_loss: 0.5798 - val_acc: 0.8686 - val_binary_crossentropy: 0.5798
# Epoch 5/20
#  - 5s - loss: 9.7760e-04 - acc: 1.0000 - binary_crossentropy: 9.7760e-04 - val_loss: 0.6759 - val_acc: 0.8698 - val_binary_crossentropy: 0.6759
# Epoch 6/20
#  - 5s - loss: 2.4172e-04 - acc: 1.0000 - binary_crossentropy: 2.4172e-04 - val_loss: 0.7154 - val_acc: 0.8702 - val_binary_crossentropy: 0.7154
# Epoch 7/20
#  - 5s - loss: 1.4695e-04 - acc: 1.0000 - binary_crossentropy: 1.4695e-04 - val_loss: 0.7404 - val_acc: 0.8704 - val_binary_crossentropy: 0.7404
# Epoch 8/20
#  - 5s - loss: 1.0528e-04 - acc: 1.0000 - binary_crossentropy: 1.0528e-04 - val_loss: 0.7590 - val_acc: 0.8708 - val_binary_crossentropy: 0.7590
# Epoch 9/20
#  - 5s - loss: 8.0070e-05 - acc: 1.0000 - binary_crossentropy: 8.0070e-05 - val_loss: 0.7748 - val_acc: 0.8707 - val_binary_crossentropy: 0.7748
# Epoch 10/20
#  - 5s - loss: 6.3198e-05 - acc: 1.0000 - binary_crossentropy: 6.3198e-05 - val_loss: 0.7871 - val_acc: 0.8708 - val_binary_crossentropy: 0.7871
# Epoch 11/20
#  - 5s - loss: 5.1217e-05 - acc: 1.0000 - binary_crossentropy: 5.1217e-05 - val_loss: 0.7995 - val_acc: 0.8707 - val_binary_crossentropy: 0.7995
# Epoch 12/20
#  - 5s - loss: 4.2190e-05 - acc: 1.0000 - binary_crossentropy: 4.2190e-05 - val_loss: 0.8099 - val_acc: 0.8708 - val_binary_crossentropy: 0.8099
# Epoch 13/20
#  - 5s - loss: 3.5370e-05 - acc: 1.0000 - binary_crossentropy: 3.5370e-05 - val_loss: 0.8187 - val_acc: 0.8708 - val_binary_crossentropy: 0.8187
# Epoch 14/20
#  - 5s - loss: 3.0073e-05 - acc: 1.0000 - binary_crossentropy: 3.0073e-05 - val_loss: 0.8277 - val_acc: 0.8708 - val_binary_crossentropy: 0.8277
# Epoch 15/20
#  - 5s - loss: 2.5835e-05 - acc: 1.0000 - binary_crossentropy: 2.5835e-05 - val_loss: 0.8358 - val_acc: 0.8710 - val_binary_crossentropy: 0.8358
# Epoch 16/20
#  - 5s - loss: 2.2440e-05 - acc: 1.0000 - binary_crossentropy: 2.2440e-05 - val_loss: 0.8426 - val_acc: 0.8709 - val_binary_crossentropy: 0.8426
# Epoch 17/20
#  - 5s - loss: 1.9639e-05 - acc: 1.0000 - binary_crossentropy: 1.9639e-05 - val_loss: 0.8500 - val_acc: 0.8710 - val_binary_crossentropy: 0.8500
# Epoch 18/20
#  - 5s - loss: 1.7315e-05 - acc: 1.0000 - binary_crossentropy: 1.7315e-05 - val_loss: 0.8561 - val_acc: 0.8710 - val_binary_crossentropy: 0.8561
# Epoch 19/20
#  - 5s - loss: 1.5368e-05 - acc: 1.0000 - binary_crossentropy: 1.5368e-05 - val_loss: 0.8617 - val_acc: 0.8709 - val_binary_crossentropy: 0.8617
# Epoch 20/20
#  - 5s - loss: 1.3741e-05 - acc: 1.0000 - binary_crossentropy: 1.3741e-05 - val_loss: 0.8685 - val_acc: 0.8707 - val_binary_crossentropy: 0.8685

# %% [markdown]
# ### Plot the training and validation loss

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))
    
  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# ## Strategies

# %% [markdown]
# ### Add weight regularization

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.5249 - acc: 0.8056 - binary_crossentropy: 0.4841 - val_loss: 0.3822 - val_acc: 0.8768 - val_binary_crossentropy: 0.3392
# Epoch 2/20
#  - 2s - loss: 0.3087 - acc: 0.9072 - binary_crossentropy: 0.2617 - val_loss: 0.3360 - val_acc: 0.8871 - val_binary_crossentropy: 0.2860
# Epoch 3/20
#  - 3s - loss: 0.2590 - acc: 0.9271 - binary_crossentropy: 0.2067 - val_loss: 0.3366 - val_acc: 0.8859 - val_binary_crossentropy: 0.2826
# Epoch 4/20
#  - 3s - loss: 0.2344 - acc: 0.9386 - binary_crossentropy: 0.1790 - val_loss: 0.3459 - val_acc: 0.8836 - val_binary_crossentropy: 0.2895
# Epoch 5/20
#  - 3s - loss: 0.2211 - acc: 0.9446 - binary_crossentropy: 0.1632 - val_loss: 0.3587 - val_acc: 0.8803 - val_binary_crossentropy: 0.2999
# Epoch 6/20
#  - 3s - loss: 0.2084 - acc: 0.9497 - binary_crossentropy: 0.1490 - val_loss: 0.3713 - val_acc: 0.8770 - val_binary_crossentropy: 0.3116
# Epoch 7/20
#  - 3s - loss: 0.2016 - acc: 0.9525 - binary_crossentropy: 0.1409 - val_loss: 0.3868 - val_acc: 0.8736 - val_binary_crossentropy: 0.3254
# Epoch 8/20
#  - 2s - loss: 0.1933 - acc: 0.9560 - binary_crossentropy: 0.1313 - val_loss: 0.3942 - val_acc: 0.8729 - val_binary_crossentropy: 0.3320
# Epoch 9/20
#  - 3s - loss: 0.1880 - acc: 0.9579 - binary_crossentropy: 0.1254 - val_loss: 0.4090 - val_acc: 0.8706 - val_binary_crossentropy: 0.3458
# Epoch 10/20
#  - 3s - loss: 0.1862 - acc: 0.9588 - binary_crossentropy: 0.1225 - val_loss: 0.4284 - val_acc: 0.8666 - val_binary_crossentropy: 0.3644
# Epoch 11/20
#  - 3s - loss: 0.1817 - acc: 0.9606 - binary_crossentropy: 0.1172 - val_loss: 0.4329 - val_acc: 0.8674 - val_binary_crossentropy: 0.3678
# Epoch 12/20
#  - 2s - loss: 0.1781 - acc: 0.9615 - binary_crossentropy: 0.1130 - val_loss: 0.4531 - val_acc: 0.8633 - val_binary_crossentropy: 0.3877
# Epoch 13/20
#  - 3s - loss: 0.1782 - acc: 0.9614 - binary_crossentropy: 0.1120 - val_loss: 0.4559 - val_acc: 0.8644 - val_binary_crossentropy: 0.3894
# Epoch 14/20
#  - 2s - loss: 0.1694 - acc: 0.9661 - binary_crossentropy: 0.1029 - val_loss: 0.4652 - val_acc: 0.8606 - val_binary_crossentropy: 0.3990
# Epoch 15/20
#  - 2s - loss: 0.1646 - acc: 0.9674 - binary_crossentropy: 0.0984 - val_loss: 0.4802 - val_acc: 0.8615 - val_binary_crossentropy: 0.4138
# Epoch 16/20
#  - 2s - loss: 0.1620 - acc: 0.9688 - binary_crossentropy: 0.0954 - val_loss: 0.4923 - val_acc: 0.8590 - val_binary_crossentropy: 0.4256
# Epoch 17/20
#  - 3s - loss: 0.1612 - acc: 0.9678 - binary_crossentropy: 0.0944 - val_loss: 0.5026 - val_acc: 0.8572 - val_binary_crossentropy: 0.4354
# Epoch 18/20
#  - 2s - loss: 0.1596 - acc: 0.9684 - binary_crossentropy: 0.0921 - val_loss: 0.5203 - val_acc: 0.8568 - val_binary_crossentropy: 0.4525
# Epoch 19/20
#  - 3s - loss: 0.1583 - acc: 0.9683 - binary_crossentropy: 0.0902 - val_loss: 0.5253 - val_acc: 0.8584 - val_binary_crossentropy: 0.4570
# Epoch 20/20
#  - 3s - loss: 0.1563 - acc: 0.9700 - binary_crossentropy: 0.0876 - val_loss: 0.5381 - val_acc: 0.8545 - val_binary_crossentropy: 0.4693

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
# ### Add dropout

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 4s - loss: 0.6199 - acc: 0.6495 - binary_crossentropy: 0.6199 - val_loss: 0.4673 - val_acc: 0.8527 - val_binary_crossentropy: 0.4673
# Epoch 2/20
#  - 3s - loss: 0.4462 - acc: 0.8142 - binary_crossentropy: 0.4462 - val_loss: 0.3380 - val_acc: 0.8815 - val_binary_crossentropy: 0.3380
# Epoch 3/20
#  - 3s - loss: 0.3471 - acc: 0.8692 - binary_crossentropy: 0.3471 - val_loss: 0.2868 - val_acc: 0.8872 - val_binary_crossentropy: 0.2868
# Epoch 4/20
#  - 3s - loss: 0.2899 - acc: 0.8938 - binary_crossentropy: 0.2899 - val_loss: 0.2747 - val_acc: 0.8876 - val_binary_crossentropy: 0.2747
# Epoch 5/20
#  - 3s - loss: 0.2469 - acc: 0.9102 - binary_crossentropy: 0.2469 - val_loss: 0.2806 - val_acc: 0.8881 - val_binary_crossentropy: 0.2806
# Epoch 6/20
#  - 3s - loss: 0.2143 - acc: 0.9260 - binary_crossentropy: 0.2143 - val_loss: 0.2910 - val_acc: 0.8859 - val_binary_crossentropy: 0.2910
# Epoch 7/20
#  - 3s - loss: 0.1932 - acc: 0.9312 - binary_crossentropy: 0.1932 - val_loss: 0.3147 - val_acc: 0.8833 - val_binary_crossentropy: 0.3147
# Epoch 8/20
#  - 3s - loss: 0.1755 - acc: 0.9374 - binary_crossentropy: 0.1755 - val_loss: 0.3183 - val_acc: 0.8813 - val_binary_crossentropy: 0.3183
# Epoch 9/20
#  - 3s - loss: 0.1620 - acc: 0.9431 - binary_crossentropy: 0.1620 - val_loss: 0.3264 - val_acc: 0.8818 - val_binary_crossentropy: 0.3264
# Epoch 10/20
#  - 3s - loss: 0.1442 - acc: 0.9469 - binary_crossentropy: 0.1442 - val_loss: 0.3465 - val_acc: 0.8815 - val_binary_crossentropy: 0.3465
# Epoch 11/20
#  - 3s - loss: 0.1344 - acc: 0.9495 - binary_crossentropy: 0.1344 - val_loss: 0.3665 - val_acc: 0.8789 - val_binary_crossentropy: 0.3665
# Epoch 12/20
#  - 3s - loss: 0.1255 - acc: 0.9540 - binary_crossentropy: 0.1255 - val_loss: 0.3920 - val_acc: 0.8784 - val_binary_crossentropy: 0.3920
# Epoch 13/20
#  - 3s - loss: 0.1168 - acc: 0.9553 - binary_crossentropy: 0.1168 - val_loss: 0.4147 - val_acc: 0.8791 - val_binary_crossentropy: 0.4147
# Epoch 14/20
#  - 3s - loss: 0.1113 - acc: 0.9578 - binary_crossentropy: 0.1113 - val_loss: 0.4271 - val_acc: 0.8770 - val_binary_crossentropy: 0.4271
# Epoch 15/20
#  - 3s - loss: 0.1003 - acc: 0.9588 - binary_crossentropy: 0.1003 - val_loss: 0.4451 - val_acc: 0.8764 - val_binary_crossentropy: 0.4451
# Epoch 16/20
#  - 3s - loss: 0.0983 - acc: 0.9610 - binary_crossentropy: 0.0983 - val_loss: 0.4715 - val_acc: 0.8753 - val_binary_crossentropy: 0.4715
# Epoch 17/20
#  - 3s - loss: 0.0926 - acc: 0.9600 - binary_crossentropy: 0.0926 - val_loss: 0.4884 - val_acc: 0.8747 - val_binary_crossentropy: 0.4884
# Epoch 18/20
#  - 3s - loss: 0.0858 - acc: 0.9636 - binary_crossentropy: 0.0858 - val_loss: 0.5212 - val_acc: 0.8750 - val_binary_crossentropy: 0.5212
# Epoch 19/20
#  - 3s - loss: 0.0854 - acc: 0.9628 - binary_crossentropy: 0.0854 - val_loss: 0.5373 - val_acc: 0.8746 - val_binary_crossentropy: 0.5373
# Epoch 20/20
#  - 3s - loss: 0.0814 - acc: 0.9645 - binary_crossentropy: 0.0814 - val_loss: 0.5385 - val_acc: 0.8749 - val_binary_crossentropy: 0.5385

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])
